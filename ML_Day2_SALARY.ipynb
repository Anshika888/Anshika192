# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\DATA\SalaryGender.csv")
df
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
df.describe()
# Out:
#            Salary      Gender         Age         PhD
# count  100.000000  100.000000  100.000000  100.000000
# mean    52.524500    0.500000   46.880000    0.390000
# std     42.220933    0.502519   15.271469    0.490207
# min      0.250000    0.000000   20.000000    0.000000
# 25%     20.000000    0.000000   31.500000    0.000000
# 50%     39.300000    0.500000   49.000000    0.000000
# 75%     75.500000    1.000000   60.000000    1.000000
# max    190.000000    1.000000   77.000000    1.000000

# %%
df["Salary"]
# Out:
# 0     140.0
# 1      30.0
# 2      35.1
# 3      30.0
# 4      80.0
#       ...
# 95     18.6
# 96    152.0
# 97      1.8
# 98     35.0
# 99      4.0
# Name: Salary, Length: 100, dtype: float64

# %%
df.Salary.describe()
# Out:
# count    100.000000
# mean      52.524500
# std       42.220933
# min        0.250000
# 25%       20.000000
# 50%       39.300000
# 75%       75.500000
# max      190.000000
# Name: Salary, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.259312  0.477043  0.555560
# Gender  0.259312  1.000000  0.160580  0.184521
# Age     0.477043  0.160580  1.000000  0.353081
# PhD     0.555560  0.184521  0.353081  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),
 cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr(method="kendall") #kendall tau coefficient formula used here
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.145310  0.334499  0.477900
# Gender  0.145310  1.000000  0.159001  0.184521
# Age     0.334499  0.159001  1.000000  0.276267
# PhD     0.477900  0.184521  0.276267  1.000000

# %%
df.corr()   #pearson coefficient correlation formula used here
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.259312  0.477043  0.555560
# Gender  0.259312  1.000000  0.160580  0.184521
# Age     0.477043  0.160580  1.000000  0.353081
# PhD     0.555560  0.184521  0.353081  1.000000

# %%
sns.scatterplot(data=df,x="Salary",y="Gender")
# Out:
# <Axes: xlabel='Salary', ylabel='Gender'>

# %%
sns.scatterplot(data=df,x="Gender",y="Age",color="brown")
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.scatterplot(data=df,x="Salary",y="Age",color="pink")
# Out:
# <Axes: xlabel='Salary', ylabel='Age'>

# %%
sns.relplot(data=df,x="Salary",y="Age",color="green")

# %%
sns.relplot(data=df,x="Salary",y="Age",hue="Gender",color="blue")

# %%
plt.figure(figsize=(9,6))
plt.plot(df["Salary"],df["Age"],marker="o",linestyle="-",color="orange")
plt.title("Line Plot:Salary Vs Age ")
plt.xlabel("Salary")
plt.ylabel("Age")
plt.grid(True)
plt.show()

# %%
sns.lineplot(data=df,x="Age",y="Gender",color="black")
# Out:
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.lineplot(data=df,x="Salary",y="Age",color="black")
# Out:
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Salary', ylabel='Age'>

# %%
sns.lineplot(data=df,x="PhD",y="Salary",hue="Gender")
# Out:
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ganesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PhD', ylabel='Salary'>

# %%
#conda update conda
